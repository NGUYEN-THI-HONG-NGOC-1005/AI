# %% [markdown]
# <a href="https://colab.research.google.com/github/NGUYEN-THI-HONG-NGOC-1005/AI/blob/main/tu%E1%BA%A7n_1%2B2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open ('text.txt',mode='w') as accounts:
  accounts.write ('1 Nguyen Van A 8.0\n')
  accounts.write('2 Le Thi B 6.8\n')

# %%
with open ('text.txt',mode='w') as accounts:
  print('7:00 Nguyen Van A', file=accounts)
  print('7:01 Le Thi B', file=accounts)

# %%
with open('text.txt',mode='r') as accounts:
  print(f"{'name':<20}{'score':>20}")
  for record in accounts:
    name,score = record.split()
    print(f'{name:<20}{score:>20}')
# Out:
# name                               score
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-4fe769368169> in <module>
#       2   print(f"{'name':<20}{'score':>20}")
#       3   for record in accounts:
# ----> 4     name,score = record.split()
#       5     print(f'{name:<20}{score:>20}')
#
# ValueError: too many values to unpack (expected 2)

# %%
import pandas as pd
url='/content/csv1.csv'
dataframe=pd.read_csv(url)
dataframe.head(10)
# Out:
#                                                     STT;HỌ VÀ TÊN;MSSV;NGÀY SINH;KHOA;NGÀNH;ĐIỂM
# 1;Nguyễn Thị Hồng Ngọc;20104046;01/12/2002;Cơ K...                                           7.0
# 2;Trần Khánh Đoan;20104023;30/08/2002;Cơ Khí Ch...                                           4.0
# 3;Mai Thị Trí Tuệ;20104070;15/07/2002;Cơ Khí Ch...                                           6.0
# 4;Nguyễn Thị Trà Mi;20104041;24/03/2002;Cơ Khí ...                                           NaN
# 5;Trần Thị Mỹ Ngọc;20104045;10/10/2002;Cơ Khí C...                                           NaN
# 6;Nguyễn Vương Kim Hoàng;20104032;17/02/2002;Cơ...                                           6.0
# 7;Châu Ngọc Hoàng;20104056;20/04/2002;Cơ Khí Ch...                                           3.0
# 8;Lê Quang Triều;20104054;05/11/2002;Cơ Khí Chế...                                           5.0
# 9;Lê Khánh Lâm;20104017;18/01/2002;Cơ Khí Chế T...                                           8.0
# 10;Trần Văn Hậu;20104030;22/09/2002;Cơ Khí Chế ...                                           1.0

# %%
from openpyxl import Workbook
wb=Workbook()
sheet=wb.active
sheet['A1']='Nguyen Van A'
sheet['B1']='20104001'
sheet['A2']='Le Thi B'
sheet['B2']='20104002'
wb.save('test.xlsx')

# %%
import openpyxl
wb=openpyxl.load_workbook('test.xlsx')
sheet=wb.active
t1=sheet['A1']
t2=sheet['B1']
t3=sheet.cell(row = 2, column = 1) 
t4=sheet.cell(row = 2, column = 2)
print(t1.value, t2.value)
print(t3.value, t4.value)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-c131c385d7d4> in <module>
#       1 import openpyxl
# ----> 2 wb=openpyxl.load_workbook('test.xlsx')
#       3 sheet=wb.active
#       4 t1=sheet['A1']
#       5 t2=sheet['B1']
#
# /usr/local/lib/python3.7/dist-packages/openpyxl/reader/excel.py in load_workbook(filename, read_only, keep_vba, data_only, keep_links)
#     314     """
#     315     reader = ExcelReader(filename, read_only, keep_vba,
# --> 316                         data_only, keep_links)
#     317     reader.read()
#     318     return reader.wb
#
# /usr/local/lib/python3.7/dist-packages/openpyxl/reader/excel.py in __init__(self, fn, read_only, keep_vba, data_only, keep_links)
#     122     def __init__(self,  fn, read_only=False, keep_vba=KEEP_VBA,
#     123                   data_only=False, keep_links=True):
# --> 124         self.archive = _validate_archive(fn)
#     125         self.valid_files = self.archive.namelist()
#     126         self.read_only = read_only
#
# /usr/local/lib/python3.7/dist-packages/openpyxl/reader/excel.py in _validate_archive(filename)
#      94             raise InvalidFileException(msg)
#      95
# ---> 96     archive = ZipFile(filename, 'r')
#      97     return archive
#      98
#
# /usr/lib/python3.7/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel)
#    1238             while True:
#    1239                 try:
# -> 1240                     self.fp = io.open(file, filemode)
#    1241                 except OSError:
#    1242                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test.xlsx'

# %%
import pandas as pd
url='/AI2.csv'
dataframe = pd.read_csv(url)
dataframe = dataframe.set_index(dataframe['Khoa'])
dataframe[dataframe['Khoa'] == 'CKM'].head(5)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-4d944f9e668a> in <module>
#       1 import pandas as pd
#       2 url='/AI2.csv'
# ----> 3 dataframe = pd.read_csv(url)
#       4 dataframe = dataframe.set_index(dataframe['Khoa'])
#       5 dataframe[dataframe['Khoa'] == 'CKM'].head(5)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/AI2.csv'

# %%
import openpyxl
wb=openpyxl.load_workbook('test.xlsx')
sheet=wb.active
t1=sheet['A1']
t2=sheet['B1']
t3=sheet.cell(row=2, column=1) 
t4=sheet.cell(row=2, column=2)
print(t1.value, t2.value)
print(t3.value, t4.value)
# Out:
# Nguyen Van A 20104001
# Le Thi B 20104002

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange (6)
y=x+1
plt.plot(x,y,'o--')
plt.show()

# %%
plt.plot(x,y,'o--')
plt.plot(x,-y,'o-')
plt.title('y=x và y=-x')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
N=16
x=np.linspace(0,15,16)
y=x
plt.plot(x,y,'o--')
plt.axis('off')
plt.show()

# %%
N=16
x=np.linspace(0,15,16)
y=np.linspace(0.1,2,16)
plt.plot(x,y,'--o')

# %%
x=[4,5,3,1,6,7]
plt.plot(x)
plt.show()

# %%
x=np.arange(25)
plt.plot(x)
plt.show()

# %%
x=np.arange(25)
plt.plot(x,x**3+1)
plt.show()

# %%
x=np.arange(25)
plt.plot(x,-x**2,'-')
plt.plot(x,-x**3,'--')
plt.plot(x,-2*x,'-.')
plt.plot(x,-2**x,':')
plt.show()

# %%
x=np.arange(7)
plt.plot(x,-x**2,'-',x,-x**3,'--',x,-2*x,'-.',x,-2**x,':')
plt.grid(True)
plt.savefig('lest png')
plt.show()

# %%
x=np.arange(3)
plt.subplots_adjust(wspace=0.3,hspace=0.3)
plt.subplot(3,2,1)
plt.plot(x,x**2,color='g')
plt.subplot(2,2,2)
plt.plot(x,x**3,color='g')
plt.subplot(2,2,3)
plt.plot(x,-2*x,color='b')
plt.subplot(2,2,4)
plt.plot(x,-2**x,'o')
plt.show()

# %%
plt.axis([0,150,0,100])
plt.scatter(60,50,s=1000,color='b',alpha=1)
plt.scatter(80,50,s=1000,color='r',alpha=.3)
plt.scatter(100,50,s=1000,color='y',alpha=.1)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot([20,50],[70,90],linewidth=5,color='r')
plt.text(100,130,'text')
plt.show()

# %%
x=np.arange(4)
y=np.arange(4)
plt.bar(x,y)
plt.show()

# %%
y=np.random.rand(3,4)
plt.bar(x+0,y[0],color='b',width=0.25)
plt.bar(x+0.25,y[1],color='y',width=0.25)
plt.bar(x+0.5,y[2],color='r',width=0.25)
plt.show()

# %%
x=np.arange(4)
y=np.random.rand(4)
plt.barh(x,y)
plt.show()

# %%
N=1000
x=np.random.rand(N)
y=np.random.rand(N)
colors=np.random.rand(N)
size=20
plt.scatter(x,y,s=size,c=colors,alpha=1)
plt.show()

# %%
import pandas as pd
url = 'http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data
# Out:
#       Year      City       Sport      Discipline  NOC            Event  \
# 0     1924  Chamonix     Skating  Figure skating  AUT       individual
# 1     1924  Chamonix     Skating  Figure skating  AUT       individual
# 2     1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3     1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# ...    ...       ...         ...             ...  ...              ...
# 2306  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2307  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2308  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2309  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
# 2310  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# 2               X    Gold
# 3               M  Bronze
# 4               M    Gold
# ...           ...     ...
# 2306            M  Silver
# 2307            W    Gold
# 2308            W  Silver
# 2309            M    Gold
# 2310            W  Silver
#
# [2311 rows x 8 columns]

# %%
import pandas as pd
url = 'http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data
data[data['NOC'] == 'USA'].head(5)
# Out:
#     Year        City       Sport      Discipline  NOC                 Event  \
# 45  1924    Chamonix  Ice Hockey      Ice Hockey  USA            ice hockey
# 46  1924    Chamonix     Skating  Figure skating  USA            individual
# 47  1924    Chamonix     Skating   Speed skating  USA                  500m
# 48  1924    Chamonix      Skiing     Ski Jumping  USA  K90 individual (70m)
# 84  1928  St. Moritz   Bobsleigh       Bobsleigh  USA              five-man
#
#    Event gender   Medal
# 45            M  Silver
# 46            W  Silver
# 47            M    Gold
# 48            M  Bronze
# 84            M    Gold

# %%
import pandas as pd
url = 'http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data
data['NOC'].value_counts()
# Out:
# NOR    280
# USA    216
# URS    194
# AUT    185
# GER    158
# FIN    151
# CAN    119
# SUI    118
# SWE    118
# GDR    110
# ITA    101
# FRA     83
# NED     78
# RUS     76
# FRG     41
# CHN     33
# JPN     32
# KOR     31
# TCH     25
# EUN     23
# GBR     21
# EUA     19
# CZE     10
# LIE      9
# POL      8
# CRO      7
# BUL      6
# EST      6
# AUS      6
# BLR      6
# HUN      6
# UKR      5
# BEL      5
# KAZ      5
# YUG      4
# SLO      4
# ESP      2
# PRK      2
# LUX      2
# LAT      1
# ROU      1
# DEN      1
# UZB      1
# NZL      1
# SVK      1
# Name: NOC, dtype: int64

# %%
pip install scikit-fuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scikit-fuzzy in /usr/local/lib/python3.7/dist-packages (0.4.2)
# Requirement already satisfied: numpy>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from scikit-fuzzy) (1.21.6)
# Requirement already satisfied: scipy>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from scikit-fuzzy) (1.7.3)
# Requirement already satisfied: networkx>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from scikit-fuzzy) (2.6.3)

# %%
import numpy as np
import skfuzzy as fuzz

# %%
import numpy as np
import skfuzzy as fuzz
x=np.arange(m)
mfx=fu
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-fbfde16325e0> in <module>
#       1 import numpy as np
#       2 import skfuzzy as fuzz
# ----> 3 x=np.arange(m)
#       4 mfx=fu
#
# NameError: name 'm' is not defined

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl
food=ctrl.Antecedent(np.arange(0,11,1),'good')
service=ctrl.Antecedent(np.arange(0,11,1),'servise')
tip=ctrl.Consequent(np.arange(10,26,1),'tip')
food['poor']=fuzz.trimf(food.universe,[0,0,5])
food['average']=fuzz.trimf(food.universe,[0,5,10])
food['good']=fuzz.trimf(food.universe,[0,5,10])
service['poor']=fuzz.trimf(service.universe,[0,5,10])
service['average']=fuzz.trimf(service.universe,[0,5,10])
service['good']=fuzz.trimf(service.universe,[0,5,10])
tip['less']=fuzz.trimf(tip.universe,[10,14,18])
tip['normal']=fuzz.trimf(tip.universe,[14,18,22])
tip['much']=fuzz.trimf(tip.universe,[18,22,25])
service.view()
food.view()
tip.view()
